# %% [markdown]
# # Building and executing Translator queries using TCT
#
# This notebook provides examples of the usage of the `TCT.translator_query` module.

# %%
from TCT import name_resolver, translator_query

# %% [markdown]
# We want to answer questions of the form, what is a path between node A and node B?

# %%
name_resolver.lookup?
# Out:
# Signature:
# name_resolver.lookup(
#     query: str,
#     return_top_response: bool = True,
#     return_synonyms: bool = False,
#     **kwargs,
# )
# Docstring:
# A wrapper around the `lookup` api endpoint. Given a query string, this returns a TranslatorNode object or a list of TranslatorNode objects corresponding to the given name.
#
# Parameters
# ----------
# query : str
#     Query string
# return_top_response : bool
#     If true, this returns only the top response. If false, this returns a list of all responses. Default: True
# return_synonyms : bool
#     If true, the resulting TranslatorNode objects contain a list of synonyms. If false, they do not include synonyms. Default: False
# **kwargs
#     Other arguments to `lookup`. Some possible arguments: `limit=20` would limit the results to 20. `autocomplete=True` indicates that the query string can be incomplete. `biolink_type="biolink:Disease` indicates that all returned results should be diseases. For more examples, see [this](https://name-lookup.ci.transltr.io/docs#/lookup/lookup_curies_get_lookup_get).
#
# Returns
# -------
# TranslatorNode object if return_top_response is True, list of TranslatorNode objects if return_top_response is False
#
# Examples
# --------
# >>> lookup('AML')
# TranslatorNode(curie='MONDO:0018874', label='acute myeloid leukemia', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None)
# File:      ~/Translator_component_toolkit/TCT/name_resolver.py
# Type:      function

# %%
results = name_resolver.lookup('IFNG', return_top_response=False, biolink_type='biolink:Gene')
node1 = [r for r in results if 'NCBITaxon:9606' in r.taxa][0]

# %%
node2 = name_resolver.lookup('COVID-19', return_top_response=True, biolink_type='biolink:Disease')

# %%
node1
# Out:
# TranslatorNode(curie='NCBIGene:3458', label='IFNG', types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin', 'biolink:Protein', 'biolink:GeneProductMixin', 'biolink:Polypeptide', 'biolink:ChemicalEntityOrProteinOrPolypeptide'], synonyms=None, curie_synonyms=None, attributes=None, taxa=['NCBITaxon:9606'])

# %%
node2
# Out:
# TranslatorNode(curie='MONDO:0100096', label='COVID-19', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[])

# %% [markdown]
# ## Getting available Translator APIs
#
# This is done using the function `translator_query.get_translator_API_predicates`

# %%
APInames, metaKG, API_predicates = translator_query.get_translator_API_predicates()
# Out:
# 55
# (10593, 5)
# (22116, 5)

# %%
APInames
# Out:
# {'BioThings Explorer (BTE) TRAPI': 'https://bte.transltr.io/v1/query/',
#  'imProving Agent for TRAPI 1.5': 'https://ia.transltr.io/api/v1.5/query/',
#  'mediKanren': 'https://medikanren-trapi.transltr.io/query/',
#  'ARAX Translator Reasoner - TRAPI 1.6.0': 'https://arax.transltr.io/api/arax/v1.4/query/',
#  'Multiomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/multiomics/query',
#  'Automat-hetionet(Trapi v1.5.0)': 'https://automat.transltr.io/hetio/query/',
#  'COHD TRAPI': 'https://cohd-api.transltr.io/api/query/',
#  'Service Provider TRAPI': 'https://bte.transltr.io/v1/team/Service%20Provider/query/',
#  'Text Mined Cooccurrence API': 'https://cooccurrence.transltr.io/query/',
#  'Microbiome KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/mbkp/query',
#  'Drug Approvals KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/dakp/query',
#  'Genetics Data Provider for NCATS Biomedical Translator Reasoners': 'https://genetics-kp.transltr.io/genetics_provider/trapi/v1.5/query/',
#  'Aragorn(Trapi v1.5.0)': 'https://aragorn.transltr.io/aragorn/query/',
#  'Gene-List Network Enrichment Analysis': 'https://translator.broadinstitute.org/gelinea-trapi/v1.5/query/',
#  'MolePro': 'https://molepro-trapi.transltr.io/molepro/trapi/v1.5/query/',
#  'Automat-panther(Trapi v1.5.0)': 'https://automat.transltr.io/panther/query/',
#  'OpenPredict API': 'https://openpredict.transltr.io/query/',
#  'Clinical Trials KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/ctkp/query',
#  'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/BigGIM_DrugResponse_PerformancePhase/query',
#  'RTX KG2 - TRAPI 1.5.0': 'https://kg2cploverdb.ci.transltr.io/kg2c/query',
#  'Connections Hypothesis Provider API': 'https://chp-api.transltr.io/query/',
#  'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': 'https://multiomics.rtx.ai:9990/PharmacogenomicsKG/query',
#  'Automat-string-db(Trapi v1.5.0)': 'https://automat.transltr.io/string-db/query/',
#  'Automat-ehr-may-treat-kp(Trapi v1.5.0)': 'https://automat.renci.org/ehr-may-treat-kp/query/',
#  'Automat-gtopdb(Trapi v1.5.0)': 'https://automat.transltr.io/gtopdb/query/',
#  'Automat-robokop(Trapi v1.5.0)': 'https://automat.transltr.io/robokopkg/query/',
#  'Automat-cam-kp(Trapi v1.5.0)': 'https://automat.transltr.io/cam-kp/query/',
#  'Automat-gwas-catalog(Trapi v1.5.0)': 'https://automat.transltr.io/gwas-catalog/query/',
#  'Automat-hgnc(Trapi v1.5.0)': 'https://automat.transltr.io/hgnc/query/',
#  'Automat-ubergraph(Trapi v1.5.0)': 'https://automat.transltr.io/ubergraph/query/',
#  'Automat-viral-proteome(Trapi v1.5.0)': 'https://automat.transltr.io/viral-proteome/query/',
#  'Automat-ehr-clinical-connections-kp(Trapi v1.5.0)': 'https://automat.renci.org/ehr-clinical-connections-kp/query/',
#  'Automat-icees-kg(Trapi v1.5.0)': 'https://automat.transltr.io/icees-kg/query/',
#  'Automat-monarchinitiative(Trapi v1.5.0)': 'https://automat.transltr.io/monarch-kg/query/',
#  'Automat-human-goa(Trapi v1.5.0)': 'https://automat.transltr.io/human-goa/query/',
#  'Sri-node-normalizer(Trapi v1.5.0)': 'https://nodenorm.transltr.io/1.5/query/',
#  'Automat-binding-db(Trapi v1.5.0)': 'https://automat.transltr.io/binding-db/query/',
#  'Sri-answer-appraiser(Trapi v1.5.0)': 'https://answerappraiser.transltr.io/query/',
#  'Automat-intact(Trapi v1.5.0)': 'https://automat.transltr.io/intact/query/',
#  'Automat-pharos(Trapi v1.5.0)': 'https://automat.transltr.io/pharos/query/',
#  'Automat-reactome(Trapi v1.5.0)': 'https://automat.transltr.io/reactome/query/',
#  'SPOKE KP for TRAPI 1.5': 'https://spokekp.transltr.io/api/v1.5/query/',
#  'Knowledge Collaboratory API': 'https://collaboratory-api.transltr.io/query/',
#  'Aragorn(Trapi v1.6.0)': 'https://aragorn.renci.org/aragorn/query/',
#  'Answer-coalesce(Trapi v1.5.0)': 'https://answer-coalesce.transltr.io/query/',
#  'Automat-hmdb(Trapi v1.5.0)': 'https://automat.transltr.io/hmdb/query/',
#  'Automat-ctd(Trapi v1.5.0)': 'https://automat.transltr.io/ctd/query/',
#  'Automat-genome-alliance(Trapi v1.5.0)': 'https://automat.transltr.io/genome-alliance/query/',
#  'Automat-gtex(Trapi v1.5.0)': 'https://automat.transltr.io/gtex/query/',
#  'Automat-drug-central(Trapi v1.5.0)': 'https://automat.transltr.io/drugcentral/query/',
#  'Autonomous Relay System (ARS) TRAPI': 'https://ars-prod.transltr.io/ars/api/submit/',
#  'Cqs(Trapi v1.5.0)': 'https://cqs.ci.transltr.io/query/',
#  'Shepherd Aragorn': 'https://shepherd.renci.org/aragorn/query/',
#  'Workflow-runner(Trapi v1.5.0)': 'https://translator-workflow-runner.transltr.io/query/'}

# %%
metaKG
# Out:
#                                   API                 Predicate  \
# 0      BioThings Explorer (BTE) TRAPI   biolink:associated_with
# 1      BioThings Explorer (BTE) TRAPI   biolink:associated_with
# 2      BioThings Explorer (BTE) TRAPI   biolink:associated_with
# 3      BioThings Explorer (BTE) TRAPI        biolink:treated_by
# 4      BioThings Explorer (BTE) TRAPI        biolink:treated_by
# ...                               ...                       ...
# 22111           RTX KG2 - TRAPI 1.5.0  biolink:applied_to_treat
# 22112           RTX KG2 - TRAPI 1.5.0  biolink:applied_to_treat
# 22113           RTX KG2 - TRAPI 1.5.0  biolink:applied_to_treat
# 22114           RTX KG2 - TRAPI 1.5.0  biolink:applied_to_treat
# 22115           RTX KG2 - TRAPI 1.5.0  biolink:applied_to_treat
#
#                          Subject                     Object  \
# 0         biolink:ChemicalEntity               biolink:Gene
# 1          biolink:SmallMolecule               biolink:Gene
# 2       biolink:MolecularMixture               biolink:Gene
# 3                biolink:Disease     biolink:ChemicalEntity
# 4      biolink:PhenotypicFeature   biolink:MolecularMixture
# ...                          ...                        ...
# 22111         biolink:NamedThing            biolink:Disease
# 22112         biolink:NamedThing  biolink:PhenotypicFeature
# 22113         biolink:NamedThing  biolink:BehavioralFeature
# 22114     biolink:ChemicalEntity  biolink:BehavioralFeature
# 22115   biolink:MolecularMixture  biolink:BehavioralFeature
#
#                                                   URL
# 0                   https://bte.transltr.io/v1/query/
# 1                   https://bte.transltr.io/v1/query/
# 2                   https://bte.transltr.io/v1/query/
# 3                   https://bte.transltr.io/v1/query/
# 4                   https://bte.transltr.io/v1/query/
# ...                                               ...
# 22111  https://kg2cploverdb.ci.transltr.io/kg2c/query
# 22112  https://kg2cploverdb.ci.transltr.io/kg2c/query
# 22113  https://kg2cploverdb.ci.transltr.io/kg2c/query
# 22114  https://kg2cploverdb.ci.transltr.io/kg2c/query
# 22115  https://kg2cploverdb.ci.transltr.io/kg2c/query
#
# [22116 rows x 5 columns]

# %%
API_predicates
# Out:
# {'Automat-reactome(Trapi v1.5.0)': ['biolink:has_output',
#   'biolink:occurs_in',
#   'biolink:precedes',
#   'biolink:preceded_by',
#   'biolink:affects',
#   'biolink:disease_has_basis_in',
#   'biolink:subclass_of',
#   'biolink:has_input',
#   'biolink:located_in',
#   'biolink:has_part'],
#  'Automat-cam-kp(Trapi v1.5.0)': ['biolink:coexists_with',
#   'biolink:enabled_by',
#   'biolink:affects',
#   'biolink:capable_of',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:has_participant',
#   'biolink:acts_upstream_of_or_within_positive_effect',
#   'biolink:acts_upstream_of_negative_effect',
#   'biolink:has_phenotype',
#   'biolink:actively_involved_in',
#   'biolink:active_in',
#   'biolink:causes',
#   'biolink:enables',
#   'biolink:occurs_in',
#   'biolink:overlaps',
#   'biolink:has_input',
#   'biolink:located_in',
#   'biolink:acts_upstream_of_positive_effect',
#   'biolink:has_output',
#   'biolink:temporally_related_to',
#   'biolink:precedes',
#   'biolink:preceded_by',
#   'biolink:directly_physically_interacts_with',
#   'biolink:acts_upstream_of_or_within',
#   'biolink:regulates',
#   'biolink:acts_upstream_of_or_within_negative_effect',
#   'biolink:colocalizes_with'],
#  'Automat-gtex(Trapi v1.5.0)': ['biolink:is_missense_variant_of',
#   'biolink:is_nearby_variant_of',
#   'biolink:affects',
#   'biolink:is_splice_site_variant_of',
#   'biolink:is_nonsense_variant_of',
#   'biolink:is_frameshift_variant_of',
#   'biolink:is_synonymous_variant_of',
#   'biolink:is_non_coding_variant_of',
#   'biolink:related_to'],
#  'Microbiome KP - TRAPI 1.5.0': ['biolink:affects',
#   'biolink:associated_with',
#   'biolink:correlated_with'],
#  'Automat-intact(Trapi v1.5.0)': ['biolink:in_taxon',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of'],
#  'Automat-binding-db(Trapi v1.5.0)': ['biolink:affects',
#   'biolink:related_to',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of'],
#  'MolePro': ['biolink:diagnoses',
#   'biolink:catalyzes',
#   'biolink:affects',
#   'biolink:superclass_of',
#   'biolink:associated_with',
#   'biolink:is_side_effect_of',
#   'biolink:is_sequence_variant_of',
#   'biolink:same_as',
#   'biolink:has_sequence_variant',
#   'biolink:in_preclinical_trials_for',
#   'biolink:has_metabolite',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:has_participant',
#   'biolink:has_gene_product',
#   'biolink:derives_from',
#   'biolink:biomarker_for',
#   'biolink:is_diagnosed_by',
#   'biolink:disrupted_by',
#   'biolink:is_input_of',
#   'biolink:participates_in',
#   'biolink:is_metabolite_of',
#   'biolink:related_to_at_instance_level',
#   'biolink:has_active_ingredient',
#   'biolink:part_of',
#   'biolink:treats',
#   'biolink:has_catalyst',
#   'biolink:assesses',
#   'biolink:is_input',
#   'biolink:ameliorates_condition',
#   'biolink:expresses',
#   'biolink:is_output',
#   'biolink:has_substrate',
#   'biolink:is_assessed_by',
#   'biolink:regulated_by',
#   'biolink:has_biomarker',
#   'biolink:disrupts',
#   'biolink:located_in',
#   'biolink:has_input',
#   'biolink:has_active_metabolite',
#   'biolink:is_active_metabolite_of',
#   'biolink:expressed_in',
#   'biolink:subclass_of',
#   'biolink:location_of',
#   'biolink:correlated_with',
#   'biolink:assess',
#   'biolink:has_output',
#   'biolink:output_of',
#   'biolink:orthologous_to',
#   'biolink:physically_interacts_with',
#   'biolink:derives_into',
#   'biolink:condition_ameliorated_by',
#   'biolink:similar_to',
#   'biolink:directly_physically_interacts_with',
#   'biolink:treated_by',
#   'biolink:is_variant_of',
#   'biolink:has_variant',
#   'biolink:regulates',
#   'biolink:is_output_of',
#   'biolink:chemically_similar_to',
#   'biolink:has_side_effect',
#   'biolink:tested_by_preclinical_trials_of',
#   'biolink:is_substrate_of',
#   'biolink:gene_product_of',
#   'biolink:related_to',
#   'biolink:is_active_ingredient_of',
#   'biolink:affected_by'],
#  'BioThings Explorer (BTE) TRAPI': ['biolink:diagnoses',
#   'biolink:catalyzes',
#   'biolink:coexists_with',
#   'biolink:actively_involves',
#   'biolink:affects',
#   'biolink:contains_process',
#   'biolink:superclass_of',
#   'biolink:associated_with',
#   'biolink:subject_of_treatment_application_or_study_for_treatment_by',
#   'biolink:has_active_component',
#   'biolink:food_component_of',
#   'biolink:condition_predisposed_by',
#   'biolink:in_preclinical_trials_for',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:in_clinical_trials_for',
#   'biolink:has_gene_product',
#   'biolink:derives_from',
#   'biolink:negatively_associated_with',
#   'biolink:manifestation_of',
#   'biolink:increases_response_to',
#   'biolink:is_diagnosed_by',
#   'biolink:actively_involved_in',
#   'biolink:has_contraindication',
#   'biolink:disrupted_by',
#   'biolink:is_input_of',
#   'biolink:participates_in',
#   'biolink:preventative_for_condition',
#   'biolink:treats',
#   'biolink:part_of',
#   'biolink:associated_with_resistance_to',
#   'biolink:contribution_from',
#   'biolink:associated_with_sensitivity_to',
#   'biolink:occurs_together_in_literature_with',
#   'biolink:causes',
#   'biolink:occurs_in',
#   'biolink:disrupts',
#   'biolink:develops_into',
#   'biolink:associated_with_increased_likelihood_of',
#   'biolink:gene_associated_with_condition',
#   'biolink:caused_by',
#   'biolink:treatment_applications_from',
#   'biolink:condition_exacerbated_by',
#   'biolink:located_in',
#   'biolink:has_input',
#   'biolink:location_of',
#   'biolink:correlated_with',
#   'biolink:exacerbates_condition',
#   'biolink:condition_prevented_by',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:has_manifestation',
#   'biolink:close_match',
#   'biolink:phenotype_of',
#   'biolink:derives_into',
#   'biolink:precedes',
#   'biolink:preceded_by',
#   'biolink:contraindicated_in',
#   'biolink:physically_interacts_with',
#   'biolink:condition_associated_with_gene',
#   'biolink:similar_to',
#   'biolink:adverse_event_of',
#   'biolink:produced_by',
#   'biolink:directly_physically_interacts_with',
#   'biolink:has_food_component',
#   'biolink:treated_by',
#   'biolink:positively_correlated_with',
#   'biolink:predisposes_to_condition',
#   'biolink:positively_associated_with',
#   'biolink:related_to',
#   'biolink:tested_by_preclinical_trials_of',
#   'biolink:produces',
#   'biolink:negatively_correlated_with',
#   'biolink:affected_by'],
#  'Automat-hgnc(Trapi v1.5.0)': ['biolink:has_part'],
#  'Automat-ehr-may-treat-kp(Trapi v1.5.0)': ['biolink:associated_with_increased_likelihood_of'],
#  'Automat-panther(Trapi v1.5.0)': ['biolink:catalyzes',
#   'biolink:has_participant',
#   'biolink:actively_involved_in',
#   'biolink:located_in',
#   'biolink:subclass_of',
#   'biolink:has_part'],
#  'Automat-ubergraph(Trapi v1.5.0)': ['biolink:coexists_with',
#   'biolink:affects',
#   'biolink:associated_with',
#   'biolink:capable_of',
#   'biolink:homologous_to',
#   'biolink:has_part',
#   'biolink:has_participant',
#   'biolink:contributes_to',
#   'biolink:derives_from',
#   'biolink:has_phenotype',
#   'biolink:actively_involved_in',
#   'biolink:composed_primarily_of',
#   'biolink:gene_associated_with_condition',
#   'biolink:causes',
#   'biolink:occurs_in',
#   'biolink:disrupts',
#   'biolink:overlaps',
#   'biolink:has_input',
#   'biolink:acts_upstream_of',
#   'biolink:located_in',
#   'biolink:subclass_of',
#   'biolink:expressed_in',
#   'biolink:in_taxon',
#   'biolink:has_output',
#   'biolink:temporally_related_to',
#   'biolink:derives_into',
#   'biolink:precedes',
#   'biolink:preceded_by',
#   'biolink:directly_physically_interacts_with',
#   'biolink:regulates',
#   'biolink:develops_from',
#   'biolink:related_to',
#   'biolink:produces'],
#  'Genetics Data Provider for NCATS Biomedical Translator Reasoners': ['biolink:gene_associated_with_condition',
#   'biolink:condition_associated_with_gene',
#   'biolink:genetic_association'],
#  'Connections Hypothesis Provider API': ['biolink:regulates',
#   'biolink:expresses',
#   'biolink:regulated_by',
#   'biolink:expressed_in'],
#  'Service Provider TRAPI': ['biolink:food_component_of',
#   'biolink:condition_predisposed_by',
#   'biolink:is_sequence_variant_of',
#   'biolink:interacts_with',
#   'biolink:derives_from',
#   'biolink:is_diagnosed_by',
#   'biolink:associated_with_resistance_to',
#   'biolink:gene_associated_with_condition',
#   'biolink:enables',
#   'biolink:genetically_interacts_with',
#   'biolink:caused_by',
#   'biolink:applied_to_treat',
#   'biolink:expressed_in',
#   'biolink:location_of',
#   'biolink:condition_prevented_by',
#   'biolink:sensitivity_associated_with',
#   'biolink:has_manifestation',
#   'biolink:studied_to_treat',
#   'biolink:contraindicated_in',
#   'biolink:target_for',
#   'biolink:has_adverse_event',
#   'biolink:diagnoses',
#   'biolink:superclass_of',
#   'biolink:in_preclinical_trials_for',
#   'biolink:has_part',
#   'biolink:has_participant',
#   'biolink:manifestation_of',
#   'biolink:biomarker_for',
#   'biolink:actively_involved_in',
#   'biolink:has_contraindication',
#   'biolink:participates_in',
#   'biolink:expresses',
#   'biolink:treats',
#   'biolink:contribution_from',
#   'biolink:associated_with_sensitivity_to',
#   'biolink:occurs_in',
#   'biolink:disrupts',
#   'biolink:subclass_of',
#   'biolink:exacerbates_condition',
#   'biolink:has_target',
#   'biolink:derives_into',
#   'biolink:precedes',
#   'biolink:treated_in_studies_by',
#   'biolink:physically_interacts_with',
#   'biolink:condition_associated_with_gene',
#   'biolink:positively_correlated_with',
#   'biolink:regulates',
#   'biolink:related_to',
#   'biolink:tested_by_preclinical_trials_of',
#   'biolink:affected_by',
#   'biolink:resistance_associated_with',
#   'biolink:has_active_component',
#   'biolink:homologous_to',
#   'biolink:has_phenotype',
#   'biolink:disrupted_by',
#   'biolink:part_of',
#   'biolink:occurs_together_in_literature_with',
#   'biolink:develops_into',
#   'biolink:treatment_applications_from',
#   'biolink:condition_exacerbated_by',
#   'biolink:located_in',
#   'biolink:has_input',
#   'biolink:correlated_with',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:close_match',
#   'biolink:preceded_by',
#   'biolink:produces',
#   'biolink:negatively_correlated_with',
#   'biolink:coexists_with',
#   'biolink:actively_involves',
#   'biolink:enabled_by',
#   'biolink:affects',
#   'biolink:contains_process',
#   'biolink:subject_of_treatment_application_or_study_for_treatment_by',
#   'biolink:associated_with',
#   'biolink:has_sequence_variant',
#   'biolink:in_clinical_trials_for',
#   'biolink:contributes_to',
#   'biolink:active_in',
#   'biolink:is_input_of',
#   'biolink:preventative_for_condition',
#   'biolink:causes',
#   'biolink:regulated_by',
#   'biolink:has_biomarker',
#   'biolink:tested_by_clinical_trials_of',
#   'biolink:phenotype_of',
#   'biolink:has_food_component',
#   'biolink:adverse_event_of',
#   'biolink:produced_by',
#   'biolink:treated_by',
#   'biolink:predisposes_to_condition',
#   'biolink:develops_from'],
#  'Automat-string-db(Trapi v1.5.0)': ['biolink:physically_interacts_with',
#   'biolink:subclass_of',
#   'biolink:homologous_to',
#   'biolink:related_to',
#   'biolink:coexpressed_with'],
#  'Multiomics KP - TRAPI 1.5.0': ['biolink:associated_with_sensitivity_to',
#   'biolink:associated_with_increased_likelihood_of',
#   'biolink:affects',
#   'biolink:associated_with',
#   'biolink:associated_with_resistance_to',
#   'biolink:correlated_with'],
#  'SPOKE KP for TRAPI 1.5': ['biolink:affects',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:in_clinical_trials_for',
#   'biolink:has_gene_product',
#   'biolink:has_phenotype',
#   'biolink:participates_in',
#   'biolink:expresses',
#   'biolink:treats',
#   'biolink:part_of',
#   'biolink:occurs_together_in_literature_with',
#   'biolink:causes',
#   'biolink:enables',
#   'biolink:subclass_of',
#   'biolink:has_input',
#   'biolink:superlass_of',
#   'biolink:correlated_with',
#   'biolink:has_output',
#   'biolink:physically_interacts_with',
#   'biolink:contraindicated_in',
#   'biolink:has_real_world_evidence_of_association_with',
#   'biolink:has_food_component',
#   'biolink:similar_to',
#   'biolink:condition_associated_with_gene',
#   'biolink:entity_regulates_entity',
#   'biolink:regulates',
#   'biolink:related_to',
#   'biolink:has_side_effect',
#   'biolink:negatively_correlated_with'],
#  'Automat-hmdb(Trapi v1.5.0)': ['biolink:affects',
#   'biolink:has_participant',
#   'biolink:subclass_of',
#   'biolink:correlated_with'],
#  'Automat-pharos(Trapi v1.5.0)': ['biolink:physically_interacts_with',
#   'biolink:affects',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of',
#   'biolink:related_to',
#   'biolink:genetically_associated_with'],
#  'Automat-gtopdb(Trapi v1.5.0)': ['biolink:has_gene_product',
#   'biolink:affects',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of',
#   'biolink:gene_product_of',
#   'biolink:has_part'],
#  'Knowledge Collaboratory API': ['biolink:associated_with',
#   'biolink:treated_by',
#   'biolink:positively_correlated_with',
#   'biolink:treats',
#   'biolink:interacts_with'],
#  'Automat-ctd(Trapi v1.5.0)': ['biolink:has_participant',
#   'biolink:contributes_to',
#   'biolink:response_affected_by',
#   'biolink:affects',
#   'biolink:increases_response_to',
#   'biolink:positively_correlated_with',
#   'biolink:subclass_of',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:related_to',
#   'biolink:negatively_correlated_with',
#   'biolink:affects_response_to',
#   'biolink:decreases_response_to'],
#  'Automat-hetionet(Trapi v1.5.0)': ['biolink:catalyzes',
#   'biolink:causes',
#   'biolink:similar_to',
#   'biolink:genetically_interacts_with',
#   'biolink:actively_involved_in',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of',
#   'biolink:regulates',
#   'biolink:related_to',
#   'biolink:expressed_in',
#   'biolink:treats',
#   'biolink:ameliorates_condition',
#   'biolink:correlated_with',
#   'biolink:has_part'],
#  'Automat-human-goa(Trapi v1.5.0)': ['biolink:catalyzes',
#   'biolink:contributes_to',
#   'biolink:acts_upstream_of_or_within_positive_effect',
#   'biolink:affects',
#   'biolink:acts_upstream_of_negative_effect',
#   'biolink:active_in',
#   'biolink:actively_involved_in',
#   'biolink:subclass_of',
#   'biolink:acts_upstream_of',
#   'biolink:located_in',
#   'biolink:has_part',
#   'biolink:acts_upstream_of_or_within_negative_effect',
#   'biolink:acts_upstream_of_positive_effect',
#   'biolink:colocalizes_with'],
#  'Text Mined Cooccurrence API': ['biolink:occurs_together_in_literature_with'],
#  'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0': ['biolink:gene_associated_with_condition',
#   'biolink:associated_with_sensitivity_to',
#   'biolink:physically_interacts_with',
#   'biolink:biomarker_for',
#   'biolink:genetically_interacts_with',
#   'biolink:expressed_in',
#   'biolink:associated_with_resistance_to'],
#  'Automat-monarchinitiative(Trapi v1.5.0)': ['biolink:enabled_by',
#   'biolink:is_sequence_variant_of',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:model_of',
#   'biolink:has_participant',
#   'biolink:contributes_to',
#   'biolink:acts_upstream_of_or_within_positive_effect',
#   'biolink:acts_upstream_of_negative_effect',
#   'biolink:actively_involved_in',
#   'biolink:has_phenotype',
#   'biolink:active_in',
#   'biolink:participates_in',
#   'biolink:genetically_associated_with',
#   'biolink:part_of',
#   'biolink:gene_associated_with_condition',
#   'biolink:associated_with_increased_likelihood_of',
#   'biolink:causes',
#   'biolink:enables',
#   'biolink:subclass_of',
#   'biolink:acts_upstream_of',
#   'biolink:located_in',
#   'biolink:expressed_in',
#   'biolink:has_mode_of_inheritance',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:acts_upstream_of_positive_effect',
#   'biolink:orthologous_to',
#   'biolink:acts_upstream_of_or_within',
#   'biolink:related_to',
#   'biolink:acts_upstream_of_or_within_negative_effect',
#   'biolink:colocalizes_with'],
#  'CATRAX Pharmacogenomics KP - TRAPI 1.5.0': ['biolink:affects',
#   'biolink:in_complex_with',
#   'biolink:biomarker_for',
#   'biolink:associated_with',
#   'biolink:regulates'],
#  'Automat-viral-proteome(Trapi v1.5.0)': ['biolink:catalyzes',
#   'biolink:active_in',
#   'biolink:actively_involved_in',
#   'biolink:subclass_of',
#   'biolink:acts_upstream_of',
#   'biolink:located_in',
#   'biolink:has_part',
#   'biolink:colocalizes_with'],
#  'Automat-gwas-catalog(Trapi v1.5.0)': ['biolink:is_missense_variant_of',
#   'biolink:is_nearby_variant_of',
#   'biolink:is_splice_site_variant_of',
#   'biolink:has_phenotype',
#   'biolink:is_nonsense_variant_of',
#   'biolink:subclass_of',
#   'biolink:is_frameshift_variant_of',
#   'biolink:is_synonymous_variant_of',
#   'biolink:is_non_coding_variant_of',
#   'biolink:related_to'],
#  'Gene-List Network Enrichment Analysis': ['biolink:enriched_in'],
#  'Automat-drug-central(Trapi v1.5.0)': ['biolink:diagnoses',
#   'biolink:contraindicated_in',
#   'biolink:physically_interacts_with',
#   'biolink:affects',
#   'biolink:applied_to_treat',
#   'biolink:directly_physically_interacts_with',
#   'biolink:subclass_of',
#   'biolink:preventative_for_condition',
#   'biolink:related_to',
#   'biolink:treats',
#   'biolink:has_adverse_event'],
#  'Automat-genome-alliance(Trapi v1.5.0)': ['biolink:orthologous_to'],
#  'Clinical Trials KP - TRAPI 1.5.0': ['biolink:treats',
#   'biolink:in_clinical_trials_for'],
#  'Automat-icees-kg(Trapi v1.5.0)': ['biolink:positively_correlated_with',
#   'biolink:negatively_correlated_with',
#   'biolink:correlated_with'],
#  'Drug Approvals KP - TRAPI 1.5.0': ['biolink:treats',
#   'biolink:contraindicated_for',
#   'biolink:applied_to_treat'],
#  'RTX KG2 - TRAPI 1.5.0': ['biolink:diagnoses',
#   'biolink:coexists_with',
#   'biolink:affects',
#   'biolink:associated_with',
#   'biolink:capable_of',
#   'biolink:exact_match',
#   'biolink:has_not_completed',
#   'biolink:homologous_to',
#   'biolink:is_sequence_variant_of',
#   'biolink:has_metabolite',
#   'biolink:translates_to',
#   'biolink:same_as',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:indirectly_physically_interacts_with',
#   'biolink:model_of',
#   'biolink:in_clinical_trials_for',
#   'biolink:has_participant',
#   'biolink:contributes_to',
#   'biolink:derives_from',
#   'biolink:transcribed_from',
#   'biolink:manifestation_of',
#   'biolink:biomarker_for',
#   'biolink:has_phenotype',
#   'biolink:actively_involved_in',
#   'biolink:has_plasma_membrane_part',
#   'biolink:composed_primarily_of',
#   'biolink:preventative_for_condition',
#   'biolink:treats',
#   'biolink:has_increased_amount',
#   'biolink:gene_associated_with_condition',
#   'biolink:broad_match',
#   'biolink:causes',
#   'biolink:occurs_in',
#   'biolink:disrupts',
#   'biolink:enables',
#   'biolink:has_decreased_amount',
#   'biolink:applied_to_treat',
#   'biolink:subclass_of',
#   'biolink:located_in',
#   'biolink:has_input',
#   'biolink:in_taxon',
#   'biolink:expressed_in',
#   'biolink:drug_regulatory_status_world_wide',
#   'biolink:overlaps',
#   'biolink:mentions',
#   'biolink:correlated_with',
#   'biolink:exacerbates_condition',
#   'biolink:beneficial_in_models_for',
#   'biolink:has_molecular_consequence',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:close_match',
#   'biolink:lacks_part',
#   'biolink:has_output',
#   'biolink:temporally_related_to',
#   'biolink:physically_interacts_with',
#   'biolink:precedes',
#   'biolink:contraindicated_in',
#   'biolink:directly_physically_interacts_with',
#   'biolink:opposite_of',
#   'biolink:disease_has_basis_in',
#   'biolink:gene_product_of',
#   'biolink:regulates',
#   'biolink:chemically_similar_to',
#   'biolink:related_to',
#   'biolink:develops_from',
#   'biolink:disease_has_location',
#   'biolink:produces',
#   'biolink:predisposes_to_condition',
#   'biolink:colocalizes_with',
#   'biolink:has_member'],
#  'imProving Agent for TRAPI 1.5': ['biolink:affects',
#   'biolink:interacts_with',
#   'biolink:has_part',
#   'biolink:in_clinical_trials_for',
#   'biolink:has_gene_product',
#   'biolink:has_phenotype',
#   'biolink:participates_in',
#   'biolink:expresses',
#   'biolink:treats',
#   'biolink:part_of',
#   'biolink:occurs_together_in_literature_with',
#   'biolink:causes',
#   'biolink:enables',
#   'biolink:subclass_of',
#   'biolink:has_input',
#   'biolink:superlass_of',
#   'biolink:correlated_with',
#   'biolink:has_output',
#   'biolink:physically_interacts_with',
#   'biolink:contraindicated_in',
#   'biolink:has_real_world_evidence_of_association_with',
#   'biolink:has_food_component',
#   'biolink:similar_to',
#   'biolink:condition_associated_with_gene',
#   'biolink:entity_regulates_entity',
#   'biolink:regulates',
#   'biolink:related_to',
#   'biolink:has_side_effect',
#   'biolink:negatively_correlated_with'],
#  'Automat-ehr-clinical-connections-kp(Trapi v1.5.0)': ['biolink:associated_with_increased_likelihood_of',
#   'biolink:associated_with_decreased_likelihood_of'],
#  'COHD TRAPI': ['biolink:positively_correlated_with',
#   'biolink:negatively_correlated_with'],
#  'Automat-robokop(Trapi v1.5.0)': ['biolink:interacts_with',
#   'biolink:derives_from',
#   'biolink:composed_primarily_of',
#   'biolink:gene_associated_with_condition',
#   'biolink:enables',
#   'biolink:genetically_interacts_with',
#   'biolink:applied_to_treat',
#   'biolink:expressed_in',
#   'biolink:affects_response_to',
#   'biolink:has_output',
#   'biolink:contraindicated_in',
#   'biolink:target_for',
#   'biolink:disease_has_basis_in',
#   'biolink:is_non_coding_variant_of',
#   'biolink:has_adverse_event',
#   'biolink:diagnoses',
#   'biolink:catalyzes',
#   'biolink:is_splice_site_variant_of',
#   'biolink:has_part',
#   'biolink:has_participant',
#   'biolink:manifestation_of',
#   'biolink:actively_involved_in',
#   'biolink:has_active_ingredient',
#   'biolink:genetically_associated_with',
#   'biolink:treats',
#   'biolink:coexpressed_with',
#   'biolink:occurs_in',
#   'biolink:disrupts',
#   'biolink:subclass_of',
#   'biolink:is_nearby_variant_of',
#   'biolink:precedes',
#   'biolink:derives_into',
#   'biolink:physically_interacts_with',
#   'biolink:positively_correlated_with',
#   'biolink:regulates',
#   'biolink:related_to',
#   'biolink:capable_of',
#   'biolink:is_synonymous_variant_of',
#   'biolink:homologous_to',
#   'biolink:has_metabolite',
#   'biolink:has_gene_product',
#   'biolink:acts_upstream_of_or_within_positive_effect',
#   'biolink:increases_response_to',
#   'biolink:acts_upstream_of_negative_effect',
#   'biolink:has_phenotype',
#   'biolink:ameliorates_condition',
#   'biolink:is_nonsense_variant_of',
#   'biolink:located_in',
#   'biolink:has_input',
#   'biolink:in_taxon',
#   'biolink:correlated_with',
#   'biolink:treats_or_applied_or_studied_to_treat',
#   'biolink:acts_upstream_of_positive_effect',
#   'biolink:temporally_related_to',
#   'biolink:preceded_by',
#   'biolink:similar_to',
#   'biolink:directly_physically_interacts_with',
#   'biolink:gene_product_of',
#   'biolink:produces',
#   'biolink:negatively_correlated_with',
#   'biolink:acts_upstream_of_or_within_negative_effect',
#   'biolink:coexists_with',
#   'biolink:enabled_by',
#   'biolink:affects',
#   'biolink:associated_with',
#   'biolink:is_frameshift_variant_of',
#   'biolink:is_missense_variant_of',
#   'biolink:contributes_to',
#   'biolink:response_affected_by',
#   'biolink:in_complex_with',
#   'biolink:active_in',
#   'biolink:preventative_for_condition',
#   'biolink:decreases_response_to',
#   'biolink:causes',
#   'biolink:overlaps',
#   'biolink:acts_upstream_of',
#   'biolink:chemically_similar_to',
#   'biolink:develops_from',
#   'biolink:predisposes_to_condition',
#   'biolink:is_active_ingredient_of',
#   'biolink:colocalizes_with']}

# %% [markdown]
# ## Building a query
#
# Question that we want to answer: which drugs treat COVID-19?
#
# For a list of available biolink types and predicates, see https://biolink.github.io/biolink-model/
#
# In this case, we want to find all `biolink:Gene` entities that are linked to the IFNG node via the predicate `biolink:treats`.

# %%
query = translator_query.build_query_json([node1.curie], ['biolink:Gene'], ['biolink:interacts_with'])

# %%
query
# Out:
# {'message': {'query_graph': {'edges': {'e00': {'subject': 'n00',
#      'object': 'n01',
#      'predicates': ['biolink:interacts_with']}},
#    'nodes': {'n00': {'ids': ['NCBIGene:3458']},
#     'n01': {'categories': ['biolink:Gene']}}}}}

# %% [markdown]
# ## Selecting the APIs
#
# Which APIs have the relations that we are looking for?

# %%
from TCT import TCT

# %%
selected_predicates, selected_APIs, API_URLs = TCT.select_predicates_API(['biolink:Gene'], ['biolink:Gene'], metaKG, APInames)

# %%
selected_APIs
# Out:
# ['Automat-cam-kp(Trapi v1.5.0)',
#  'Microbiome KP - TRAPI 1.5.0',
#  'MolePro',
#  'BioThings Explorer (BTE) TRAPI',
#  'Automat-ehr-may-treat-kp(Trapi v1.5.0)',
#  'Connections Hypothesis Provider API',
#  'Service Provider TRAPI',
#  'Multiomics KP - TRAPI 1.5.0',
#  'SPOKE KP for TRAPI 1.5',
#  'Automat-pharos(Trapi v1.5.0)',
#  'Automat-hetionet(Trapi v1.5.0)',
#  'CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0',
#  'Automat-monarchinitiative(Trapi v1.5.0)',
#  'CATRAX Pharmacogenomics KP - TRAPI 1.5.0',
#  'Automat-genome-alliance(Trapi v1.5.0)',
#  'RTX KG2 - TRAPI 1.5.0',
#  'Automat-icees-kg(Trapi v1.5.0)',
#  'imProving Agent for TRAPI 1.5',
#  'Automat-robokop(Trapi v1.5.0)']

# %%
selected_predicates
# Out:
# ['biolink:coexists_with',
#  'biolink:affects',
#  'biolink:associated_with',
#  'biolink:capable_of',
#  'biolink:homologous_to',
#  'biolink:same_as',
#  'biolink:interacts_with',
#  'biolink:has_part',
#  'biolink:has_participant',
#  'biolink:derives_from',
#  'biolink:biomarker_for',
#  'biolink:in_complex_with',
#  'biolink:associated_with_resistance_to',
#  'biolink:part_of',
#  'biolink:genetically_associated_with',
#  'biolink:coexpressed_with',
#  'biolink:associated_with_sensitivity_to',
#  'biolink:associated_with_increased_likelihood_of',
#  'biolink:causes',
#  'biolink:regulated_by',
#  'biolink:occurs_in',
#  'biolink:genetically_interacts_with',
#  'biolink:subclass_of',
#  'biolink:has_input',
#  'biolink:correlated_with',
#  'biolink:close_match',
#  'biolink:orthologous_to',
#  'biolink:derives_into',
#  'biolink:physically_interacts_with',
#  'biolink:produced_by',
#  'biolink:directly_physically_interacts_with',
#  'biolink:positively_correlated_with',
#  'biolink:regulates',
#  'biolink:acts_upstream_of_or_within',
#  'biolink:gene_product_of',
#  'biolink:related_to',
#  'biolink:produces',
#  'biolink:negatively_correlated_with',
#  'biolink:colocalizes_with',
#  'biolink:affected_by']

# %% [markdown]
# ## Executing the query

# %%
query_result = translator_query.parallel_api_query(query, selected_APIs, APInames, API_predicates)
# Out:
# BioThings Explorer (BTE) TRAPI: Success!
# Service Provider TRAPI: Success!
# Automat-hetionet(Trapi v1.5.0): Success!
# CATRAX BigGIM DrugResponse Performance Phase KP - TRAPI 1.5.0: Success!
# CATRAX Pharmacogenomics KP - TRAPI 1.5.0: Success!
# RTX KG2 - TRAPI 1.5.0: Success!
# Automat-robokop(Trapi v1.5.0): Success!

# %%
len(query_result)
# Out:
# 2411
