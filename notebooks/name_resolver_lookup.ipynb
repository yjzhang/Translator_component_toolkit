# %% [markdown]
# # Using `name_resolver` and `node_normalizer`

# %%
from TCT import name_resolver, node_normalizer

# %% [markdown]
# ## `name_resolver`
#
# This module can be used to look up nodes and CURIEs given names of biological objects.

# %%
name_resolver.lookup('TP53')
# Out:
# TranslatorNode(curie='NCBIGene:397276', label='TP53', types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin', 'biolink:Protein', 'biolink:GeneProductMixin', 'biolink:Polypeptide', 'biolink:ChemicalEntityOrProteinOrPolypeptide'], synonyms=None, curie_synonyms=None, attributes=None, taxa=['NCBITaxon:9823'])

# %%
name_resolver.lookup('Acute Myeloid Leukemia')
# Out:
# TranslatorNode(curie='MONDO:0018874', label='acute myeloid leukemia', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[])

# %%
name_resolver.lookup('COVID-19')
# Out:
# TranslatorNode(curie='MONDO:0100096', label='COVID-19', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[])

# %% [markdown]
# ### Query parameters
#
# - Requiring specific taxa (species)
# - Selecting specific node types

# %%
name_resolver.lookup('AML', biolink_type='biolink:Disease')
# Out:
# TranslatorNode(curie='MONDO:0042982', label='GATA2 deficiency with susceptibility to MDS/AML', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[])

# %%
name_resolver.lookup('AML', biolink_type='biolink:Disease', return_top_response=False)
# Out:
# [TranslatorNode(curie='MONDO:0042982', label='GATA2 deficiency with susceptibility to MDS/AML', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='UMLS:C2861614', label='AML M5b', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='MONDO:0018874', label='acute myeloid leukemia', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='UMLS:C5225814', label='Leukemia - acute myeloid leukemia (AML)', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='UMLS:C1860794', label='Leukemia (both ALL and AML)', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='MONDO:0017893', label='inherited acute myeloid leukemia', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='UMLS:C1627934', label='AML+MDS gene CEP 8 trisomy', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='UMLS:C2861592', label='AML Me with t(15;17) and variants', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='MONDO:0044923', label='acute myeloid leukemia with mutated NPM1', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[]),
#  TranslatorNode(curie='MONDO:0100422', label='acute myeloid leukemia, RUNX1 gene mutation', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity'], synonyms=None, curie_synonyms=None, attributes=None, taxa=[])]

# %%
name_resolver.lookup('P53', only_taxa='NCBITaxon:9606', biolink_type='biolink:Gene')
# Out:
# TranslatorNode(curie='NCBIGene:7157', label='TP53', types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:Entity', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin', 'biolink:Protein', 'biolink:GeneProductMixin', 'biolink:Polypeptide', 'biolink:ChemicalEntityOrProteinOrPolypeptide'], synonyms=None, curie_synonyms=None, attributes=None, taxa=['NCBITaxon:9606'])

# %% [markdown]
# ### Bulk lookup
#
# With `bulk_lookup`, we can look up multiple names at the same time.

# %% [markdown]
# ## `node_normalizer`
#
# This module is used to get names for CURIE ids, as well as get node objects given CURIEs.

# %%
output = node_normalizer.ID_convert_to_preferred_name_nodeNormalizer(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755'])
# Out:
# NCBIGene:1055: no preferred name
# NCBIGene:28755: no preferred name

# %%
output
# Out:
# {'NCBIGene:3458': 'IFNG',
#  'MONDO:0100096': 'COVID-19',
#  'NCBIGene:1055': 'NCBIGene:1055',
#  'NCBIGene:28755': 'NCBIGene:28755'}

# %%
output = node_normalizer.get_preferred_names(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755'])
# Out:
# NCBIGene:1055: no preferred name
# NCBIGene:28755: no preferred name

# %%
output
# Out:
# {'NCBIGene:3458': 'IFNG',
#  'MONDO:0100096': 'COVID-19',
#  'NCBIGene:1055': 'NCBIGene:1055',
#  'NCBIGene:28755': 'NCBIGene:28755'}

# %%
dic_id_map = node_normalizer.ID_convert_to_preferred_name_nodeNormalizer(["NCBIGene:1234", "NCBIGene:5678"])

# %%
dic_id_map
# Out:
# {'NCBIGene:1234': 'CCR5', 'NCBIGene:5678': 'PSG9'}

# %%
output = node_normalizer.get_normalized_nodes(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755'])

# %%
output
# Out:
# {'NCBIGene:3458': TranslatorNode(curie='NCBIGene:3458', label='IFNG', types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin', 'biolink:Protein', 'biolink:GeneProductMixin', 'biolink:Polypeptide', 'biolink:ChemicalEntityOrProteinOrPolypeptide'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'MONDO:0100096': TranslatorNode(curie='MONDO:0100096', label='COVID-19', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'NCBIGene:1055': TranslatorNode(curie='NCBIGene:1055', label=None, types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'NCBIGene:28755': TranslatorNode(curie='NCBIGene:28755', label=None, types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None)}

# %%
output = node_normalizer.get_normalized_nodes(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755'], mode='post')

# %%
output
# Out:
# {'NCBIGene:3458': TranslatorNode(curie='NCBIGene:3458', label='IFNG', types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin', 'biolink:Protein', 'biolink:GeneProductMixin', 'biolink:Polypeptide', 'biolink:ChemicalEntityOrProteinOrPolypeptide'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'MONDO:0100096': TranslatorNode(curie='MONDO:0100096', label='COVID-19', types=['biolink:Disease', 'biolink:DiseaseOrPhenotypicFeature', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'NCBIGene:1055': TranslatorNode(curie='NCBIGene:1055', label=None, types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None),
#  'NCBIGene:28755': TranslatorNode(curie='NCBIGene:28755', label=None, types=['biolink:Gene', 'biolink:GeneOrGeneProduct', 'biolink:GenomicEntity', 'biolink:ChemicalEntityOrGeneOrGeneProduct', 'biolink:PhysicalEssence', 'biolink:OntologyClass', 'biolink:BiologicalEntity', 'biolink:ThingWithTaxon', 'biolink:NamedThing', 'biolink:PhysicalEssenceOrOccurrent', 'biolink:MacromolecularMachineMixin'], synonyms=None, curie_synonyms=None, attributes=None, taxa=None)}

# %%
node_normalizer.get_preferred_names(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755', 'afds;lkdasfjdf;l'])
# Out:
# NCBIGene:1055: no preferred name
# NCBIGene:28755: no preferred name
# NodeNorm does not know about these identifiers: afds;lkdasfjdf;l
# {'NCBIGene:3458': 'IFNG',
#  'MONDO:0100096': 'COVID-19',
#  'NCBIGene:1055': 'NCBIGene:1055',
#  'NCBIGene:28755': 'NCBIGene:28755'}

# %%
node_normalizer.ID_convert_to_preferred_name_nodeNormalizer(['NCBIGene:3458', 'MONDO:0100096', 'NCBIGene:1055', 'NCBIGene:28755', 'adsffdsaaf'])
# Out:
# NCBIGene:1055: no preferred name
# NCBIGene:28755: no preferred name
# NodeNorm does not know about these identifiers: adsffdsaaf
# {'NCBIGene:3458': 'IFNG',
#  'MONDO:0100096': 'COVID-19',
#  'NCBIGene:1055': 'NCBIGene:1055',
#  'NCBIGene:28755': 'NCBIGene:28755',
#  'adsffdsaaf': 'adsffdsaaf'}
